# %%
hello("Yue tu")
# Out:
# Hello Yue tu
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# Hello Machine Learning
# ...

# %%
1+2
# Out:
# 3

# %%
for _ in  range(10):
    print("Hello Yue")
# Out:
# Hello Yue
# Hello Yue
# Hello Yue
# Hello Yue
# Hello Yue
# Hello Yue
# Hello Yue
# Hello Yue
# Hello Yue
# Hello Yue

# %% [markdown]
# ###   timeit

# %%
# %timeit L= [i**2 for i in range(1000)]
# Out:
# 217 µs ± 2.11 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %time L = [i**2 for i in range(100)]
# Out:
# CPU times: user 33 µs, sys: 0 ns, total: 33 µs
# Wall time: 36 µs

# %%
# %%timeit
L = []
for n in range(1000):
    L.append(n**2)
# Out:
# 256 µs ± 5.54 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
